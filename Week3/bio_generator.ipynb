# %% [markdown]
# <a href="https://colab.research.google.com/github/KalenH0/ThinkPythonAssignments/blob/main/Week3/bio_generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import Statements

# Function Definitions

# Program Logic
# Assign values to variables: name, goal, birth_year, current_year
name = "John Smith"
goal = "I want to rule the world"
birth_year = 1971
current_year = 2026

# Calculate Age
age = current_year - birth_year
# Print top border
print("=" * 25)
# Print bio sentence
print("My name is " + name + " and I am " + str(age) + " years old.")
# Print bottom border
# Out:
# ...
# My name is John Smith and I am 55 years old.
