# %% [markdown]
# <a href="https://colab.research.google.com/github/KalenH0/ThinkPythonAssignments/blob/main/week6/week6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# 1. Import math

# FUNCTION DEFINITIONS
# 1. Define area(radius): returns pi * r squared
 def circle_area(radius):
    area = math.pi * radius**2
    return area
# 2. Define circumference(radius): returns 2 * pi * r
 def repeat_string(word, n):
    return word * n
# 3. Define volume(radius, height):
  def distance(x1, y1, x2, y2):
    dx = x2 - x1
    dy = y2 - y1
    print('dx is', dx)
    print('dy is', dy)
    return 0.0
#    - Call area(radius) and multiply by height.
#    - Return the result.

# PROGRAM LOGIC
# 1. Input for radius (float)
# 2. Call and print area and circumference.
# 3. Input for height (float)
# 4. Call and print volume.
